# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_absolute_error,mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor,RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score,KFold

# %%
df = pd.read_csv('Facebook_metrics_Clustering.csv')

# %%
df
# Out:
#      page_total_likes post_type  category  post_month  post_weekday  \
# 0              139441     Photo         2          12             4
# 1              139441    Status         2          12             3
# 2              139441     Photo         3          12             3
# 3              139441     Photo         2          12             2
# 4              139441     Photo         2          12             2
# ..                ...       ...       ...         ...           ...
# 491             85093     Photo         3           1             7
# 492             81370     Photo         2           1             5
# 493             81370     Photo         1           1             5
# 494             81370     Photo         3           1             4
# 495             81370     Photo         2           1             4
#
#      post_hour  paid  total_interactions  post_ratio_engaged_consumers  \
# 0            3   0.0                 100                      0.612360
# 1           10   0.0                 164                      0.934111
# 2            3   0.0                  80                      0.638418
# 3           10   1.0                1777                      0.357304
# 4            3   0.0                 393                      0.611028
# ..         ...   ...                 ...                           ...
# 491          2   0.0                  84                      0.965894
# 492          8   0.0                  75                      0.945996
# 493          2   0.0                 115                      0.915200
# 494         11   0.0                 136                      0.916933
# 495          4   0.0                 119                      0.929078
#
#      post_ratio_imp_reach_log  post_ratio_imp_reach_like_log  \
# 0                    1.047293                       1.056689
# 1                    1.037408                       1.070180
# 2                    1.033991                       1.054634
# 3                    1.013536                       1.066171
# 4                    1.056605                       1.080533
# ..                        ...                            ...
# 491                  0.958922                       0.975163
# 492                  1.026021                       1.058694
# 493                  1.068155                       1.093855
# 494                  1.036744                       1.047004
# 495                  1.008383                       1.013417
#
#      post_ratio_engaged_consumption_log
# 0                              0.848498
# 1                              0.920614
# 2                              0.773190
# 3                              0.591867
# 4                              0.902048
# ..                                  ...
# 491                            1.256401
# 492                            1.188572
# 493                            1.160047
# 494                            1.178239
# 495                            1.209338
#
# [496 rows x 12 columns]

# %% [markdown]
# #### PreProcessing Data
# 1. `Total_interactions` I have to handle outliers in it by applying `log` or `Sqrt` Scale
# 2. `Encoding` can Result a `Data leakage` if we didn't handle it well
# 3. Post_Type Will be added as `OneHotEncoder`

# %%
df.describe()
# Out:
#        page_total_likes    category  post_month  post_weekday   post_hour  \
# count        496.000000  496.000000  496.000000    496.000000  496.000000
# mean      123489.516129    1.883065    7.086694      4.143145    7.832661
# std        16000.557823    0.851876    3.276261      2.034469    4.378347
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       113028.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              paid  total_interactions  post_ratio_engaged_consumers  \
# count  496.000000          496.000000                    496.000000
# mean     0.278226          211.606855                      0.864408
# std      0.448578          381.252265                      0.121996
# min      0.000000            0.000000                      0.357304
# 25%      0.000000           71.000000                      0.814072
# 50%      0.000000          122.500000                      0.905741
# 75%      1.000000          228.500000                      0.953346
# max      1.000000         6334.000000                      1.000000
#
#        post_ratio_imp_reach_log  post_ratio_imp_reach_like_log  \
# count                496.000000                     496.000000
# mean                   1.037933                       1.065713
# std                    0.163646                       0.171456
# min                    0.775999                       0.861094
# 25%                    0.980253                       1.002351
# 50%                    1.015905                       1.035430
# 75%                    1.056337                       1.080672
# max                    3.151465                       3.174056
#
#        post_ratio_engaged_consumption_log
# count                          496.000000
# mean                             1.105461
# std                              0.363115
# min                              0.476016
# 25%                              0.910202
# 50%                              1.029461
# 75%                              1.182131
# max                              3.553239

# %% [markdown]
# #### Converting Total Interaction to logarithm
# 1. in `total_interactions` mean `212.120000` while std `380.233118` std > mean it will indicate a `High-Variance`
# 2. With A high-Variance or high `std` model will get confused and for Sure Error Will be huge esspicially in `r2`
# 3. Before Doing the `log` as we see `75%` was `228.5` and Max was `63334` which means it's `28x` from the max
# 4. After Doing the `log` as we see `75%` is `5.4` and Max is `8.75` but now it's `1.6x` more But the Order of them will stay the Same But we just Dicreased Effection of Highest Number

# %%
df['total_interactions'] = np.log1p(df['total_interactions'])
df['page_total_likes'] = np.log1p(df['page_total_likes'])

# %% [markdown]
# #### Define X (Features) and Y (Target)

# %%
X = df.drop(['total_interactions','post_ratio_imp_reach_log','paid'],axis=1) # we have removed them cause they was useless when we checked Feature Importancy
y = df['total_interactions']

# %%
X
# Out:
#      page_total_likes post_type  category  post_month  post_weekday  \
# 0           11.845404     Photo         2          12             4
# 1           11.845404    Status         2          12             3
# 2           11.845404     Photo         3          12             3
# 3           11.845404     Photo         2          12             2
# 4           11.845404     Photo         2          12             2
# ..                ...       ...       ...         ...           ...
# 491         11.351512     Photo         3           1             7
# 492         11.306774     Photo         2           1             5
# 493         11.306774     Photo         1           1             5
# 494         11.306774     Photo         3           1             4
# 495         11.306774     Photo         2           1             4
#
#      post_hour  post_ratio_engaged_consumers  post_ratio_imp_reach_like_log  \
# 0            3                      0.612360                       1.056689
# 1           10                      0.934111                       1.070180
# 2            3                      0.638418                       1.054634
# 3           10                      0.357304                       1.066171
# 4            3                      0.611028                       1.080533
# ..         ...                           ...                            ...
# 491          2                      0.965894                       0.975163
# 492          8                      0.945996                       1.058694
# 493          2                      0.915200                       1.093855
# 494         11                      0.916933                       1.047004
# 495          4                      0.929078                       1.013417
#
#      post_ratio_engaged_consumption_log
# 0                              0.848498
# 1                              0.920614
# 2                              0.773190
# 3                              0.591867
# 4                              0.902048
# ..                                  ...
# 491                            1.256401
# 492                            1.188572
# 493                            1.160047
# 494                            1.178239
# 495                            1.209338
#
# [496 rows x 9 columns]

# %% [markdown]
# #### ColumnsTransfer and Pipeline

# %%
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer,make_column_transformer
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.model_selection import cross_val_score,KFold
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor

# %%
column_transfer = make_column_transformer(
    (OneHotEncoder(),['post_type']),
    (StandardScaler(),['page_total_likes']),
    remainder='passthrough')

# %%
pipe = make_pipeline(
    column_transfer,RandomForestRegressor(max_depth=20,n_estimators=1000)
)
pipe2 = make_pipeline(
    column_transfer,
    GradientBoostingRegressor(
        learning_rate=0.05,
        max_depth=3,
        n_estimators=500,
        subsample=0.8,
        min_samples_split=10,
        random_state=42
    ))
pipe3 = make_pipeline(
    column_transfer,
   XGBRegressor(
        n_estimators=1800,
        learning_rate=0.01,
        max_depth=5,
        min_child_weight=1,
        colsample_bytree=1.0,
        reg_lambda=1,
        tree_method='exact',
        random_state=42,
        n_jobs=-1
    )
)
dict_model = {0:'RandomForest',
              1:'GradientBoost',
              2:'XGBoost'
             }

piplines = [pipe,pipe2,pipe3]

# %% [markdown]
# #### Cross-Validation
# 1. We have to performe A cross Validation rather than Spliting data since we have just `496` rows
# 2. I have performed 2 types of Cross Val `K-FOLD` And `RepeatedKFOLD` So we Can be Sure ABout Results

# %%
from sklearn.model_selection import cross_validate, KFold
import numpy as np

scoring_metrics = {
    'r2': 'r2',
    'mae': 'neg_mean_absolute_error',
    'mse': 'neg_mean_squared_error'
}

for i, j in enumerate(piplines):
    kf = KFold(n_splits=5, shuffle=True, random_state=2000)
    cv_results = cross_validate(j, X, y, cv=kf, scoring=scoring_metrics)
    r2_scores = cv_results['test_r2']
    mae_scores = np.abs(cv_results['test_mae'])
    mse_scores = np.abs(cv_results['test_mse'])
    print(f'Model: {dict_model[i]}')
    print(f'  R2 Scores: {r2_scores}')
    print(f'  R2 Mean:   {r2_scores.mean():.4f} (Std: {r2_scores.std():.4f})')
    print(f'  MAE Mean:  {mae_scores.mean():.4f}')
    print(f'  MSE Mean:  {mse_scores.mean():.4f}')
    print('-' * 20)
# Out:
# Model: RandomForest
#   R2 Scores: [0.77220413 0.8068925  0.79454939 0.69389921 0.78833852]
#   R2 Mean:   0.7712 (Std: 0.0402)
#   MAE Mean:  0.4182
#   MSE Mean:  0.3320
# --------------------
# Model: GradientBoost
#   R2 Scores: [0.81611291 0.84158109 0.79652458 0.75924245 0.84046209]
#   R2 Mean:   0.8108 (Std: 0.0307)
#   MAE Mean:  0.3801
#   MSE Mean:  0.2729
# --------------------
# Model: XGBoost
#   R2 Scores: [0.79911279 0.81032768 0.83661088 0.73648245 0.83540316]
#   R2 Mean:   0.8036 (Std: 0.0365)
#   MAE Mean:  0.3876
#   MSE Mean:  0.2832
# --------------------

# %%
for i, j in enumerate(piplines):
    rkf = RepeatedKFold(n_splits=5, n_repeats=10, random_state=2000)
    cv_results = cross_val_score(j, X, y, cv=rkf, scoring='r2',n_jobs=-1)
    
    print(f'Model: {dict_model[i]}')
    print(f'R2: {cv_results}')
    print(f'R2 Mean: {cv_results.mean():.4f}')
    print(f'  Std Dev: {cv_results.std():.4f}') # Low std dev = stable model
    print('-' * 20)
# Out:
# Model: RandomForest
# R2: [0.77289838 0.80246871 0.79283374 0.6960282  0.79863953 0.74324143
#  0.68392647 0.83035818 0.82386788 0.71206865 0.7169711  0.72392121
#  0.7723012  0.85507429 0.76898759 0.75255895 0.73284654 0.78230366
#  0.75909135 0.77140261 0.76352158 0.80465489 0.78828674 0.78236678
#  0.55597987 0.79032962 0.83960493 0.69367321 0.81183648 0.69231427
#  0.80759722 0.81264644 0.63631735 0.67619497 0.78040966 0.64156877
#  0.82006985 0.74359961 0.7988598  0.78527973 0.61987184 0.80772388
#  0.79220262 0.75023122 0.76093847 0.56722812 0.76416566 0.80730521
#  0.82481798 0.81189465]
# R2 Mean: 0.7565
#   Std Dev: 0.0664
# --------------------
# Model: GradientBoost
# R2: [0.80535515 0.81462423 0.80158047 0.75467687 0.842472   0.77875845
#  0.72369551 0.84006471 0.83049535 0.7742126  0.77919203 0.76206335
#  0.79001645 0.8466426  0.81099194 0.77915869 0.74991751 0.78414375
#  0.78841104 0.83297139 0.7425367  0.84755261 0.85042233 0.80461703
#  0.63125148 0.7896885  0.85839506 0.74697644 0.82653127 0.71496644
#  0.8131146  0.80620969 0.65260657 0.75349681 0.83574259 0.63577518
#  0.86624045 0.78456364 0.82013742 0.82096294 0.6798984  0.85806444
#  0.78578968 0.81472898 0.77184164 0.70250479 0.75905112 0.83147364
#  0.85361815 0.79565838]
# R2 Mean: 0.7869
#   Std Dev: 0.0559
# --------------------
# Model: XGBoost
# R2: [0.79330826 0.82118361 0.83061621 0.74565114 0.84211411 0.7500398
#  0.70523862 0.85048249 0.8326749  0.73357092 0.75966124 0.80673664
#  0.78458567 0.82999572 0.78935685 0.77530914 0.76271737 0.78714345
#  0.76136396 0.81548486 0.71920718 0.83688147 0.83651896 0.83028909
#  0.59200627 0.8314108  0.82977763 0.71952358 0.82622501 0.70269733
#  0.8010982  0.81269395 0.66266932 0.70750273 0.85241043 0.65761417
#  0.85414745 0.77644161 0.82939795 0.82541725 0.6340708  0.84251491
#  0.82827175 0.78489593 0.77132717 0.63674785 0.77455711 0.84087248
#  0.84840926 0.82402205]
# R2 Mean: 0.7813
#   Std Dev: 0.0641
# --------------------

# %% [markdown]
# #### Results Of Cross-Validation
# * It's Obvious that `Random Forest` Can't keep up with `Boosting` Algorithms
# * While Both `Boosting` Are so similar in `r2` and `std`

# %%
from sklearn.model_selection import GridSearchCV

# RandomForest parameters
rf_param_grid = {
    'randomforestregressor__n_estimators': [500, 1000],
    'randomforestregressor__max_depth': [10, 14, 20],
    'randomforestregressor__min_samples_leaf': [1, 2, 4]
}

# GradientBoost parameters
gb_param_grid = {
    'gradientboostingregressor__n_estimators': [300, 500],
    'gradientboostingregressor__learning_rate': [0.01, 0.05],
    'gradientboostingregressor__max_depth': [3, 4],
    'gradientboostingregressor__subsample': [0.7, 0.8]
}

# XGBoost Parameters
xgb_param_grid = {
    'xgbregressor__n_estimators': [1200, 1500, 1800],
    'xgbregressor__learning_rate': [0.01, 0.008],
    'xgbregressor__max_depth': [3, 4, 5],
    'xgbregressor__min_child_weight': [1, 3],
    'xgbregressor__reg_lambda': [1, 2, 5]
}


grids = [rf_param_grid, gb_param_grid, xgb_param_grid]
kf = KFold(n_splits=5, shuffle=True, random_state=2000)

best_models = []

for i, pipe_to_tune in enumerate(piplines):
    print(f"Starting GridSearch for: {dict_model[i]}...")
    grid = GridSearchCV(pipe_to_tune, param_grid=grids[i], cv=kf, scoring='r2', n_jobs=-1)
    grid.fit(X, y)
    
    print(f"Best {dict_model[i]} Score: {grid.best_score_:.4f}")
    print(f"Best Params: {grid.best_params_}\n")
    best_models.append(grid.best_estimator_)
# Out:
# Starting GridSearch for: RandomForest...
# Best RandomForest Score: 0.7740
# Best Params: {'randomforestregressor__max_depth': 20, 'randomforestregressor__min_samples_leaf': 1, 'randomforestregressor__n_estimators': 1000}
#
# Starting GridSearch for: GradientBoost...
# Best GradientBoost Score: 0.8113
# Best Params: {'gradientboostingregressor__learning_rate': 0.05, 'gradientboostingregressor__max_depth': 3, 'gradientboostingregressor__n_estimators': 500, 'gradientboostingregressor__subsample': 0.8}
#
# Starting GridSearch for: XGBoost...
# Best XGBoost Score: 0.8108
# Best Params: {'xgbregressor__learning_rate': 0.01, 'xgbregressor__max_depth': 5, 'xgbregressor__min_child_weight': 1, 'xgbregressor__n_estimators': 1800, 'xgbregressor__reg_lambda': 1}

# %% [markdown]
# #### Plot Difference Between Models in R2

# %%
folds = [1, 2, 3, 4, 5]
rf_scores = [0.7718, 0.8016, 0.7902, 0.6942, 0.7998]
gb_scores = [0.8053, 0.8146, 0.8015, 0.7546, 0.8424]
xgb_scores = [0.7933, 0.8211, 0.8306, 0.7456, 0.8421]

plt.figure(figsize=(10, 5))
plt.plot(folds, gb_scores, marker='o', label='GradientBoost', linewidth=3, color='green')
plt.plot(folds, xgb_scores, marker='o', label='XGBoost', linewidth=3, color='blue')
plt.plot(folds, rf_scores, marker='o', label='RandomForest', linewidth=2, color='gray', linestyle='--')

plt.axhline(y=0.8012,color='yellow',linestyle=':',label='XGBoost Mean')
plt.axhline(y=0.812,color='black',linestyle=':',label='GB Mean')
plt.axhline(y=0.77,color='purple',linestyle=':',label='RF Mean')
plt.title("Performance of Algorithm in Each K-Fold")
plt.xlabel("Data Group (Fold)")
plt.ylabel("R2 Score (Accuracy)")
plt.legend()
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# #### Visualising MAE

# %%
from sklearn.model_selection import cross_val_predict
y_pred = cross_val_predict(pipe2, X, y,n_jobs=-1)
errors = abs(y - y_pred)

# %%
sns.histplot(errors, kde=True, color='purple')
plt.title('Distribution of Prediction Errors (MAE)')
plt.xlabel('Error Size')
plt.show()
