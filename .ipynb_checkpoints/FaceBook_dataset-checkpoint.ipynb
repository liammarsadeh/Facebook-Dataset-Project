# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('dataset_Facebook.csv',sep=';')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0     0.0                       2752                             5091
# 1     0.0                      10460                            19057
# 2     0.0                       2413                             4373
# 3     1.0                      50128                            87991
# 4     0.0                       7244                            13594
# ..    ...                        ...                              ...
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                       178                      109
# 1                      1457                     1361
# 2                       177                      113
# 3                      2211                      790
# 4                       671                      410
# ..                      ...                      ...
# 495                     733                      708
# 496                     537                      508
# 497                     625                      572
# 498                     626                      574
# 499                     564                      524
#
#      Lifetime Post Consumptions  \
# 0                           159
# 1                          1674
# 2                           154
# 3                          1119
# 4                           580
# ..                          ...
# 495                         985
# 496                         687
# 497                         795
# 498                         832
# 499                         743
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 0                                                 3078
# 1                                                11710
# 2                                                 2812
# 3                                                61027
# 4                                                 6228
# ..                                                 ...
# 495                                               4750
# 496                                               3961
# 497                                               4742
# 498                                               4534
# 499                                               3861
#
#      Lifetime Post reach by people who like your Page  \
# 0                                                1640
# 1                                                6112
# 2                                                1503
# 3                                               32048
# 4                                                3200
# ..                                                ...
# 495                                              2876
# 496                                              2104
# 497                                              2388
# 498                                              2452
# 499                                              2200
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 0                                                  119
# 1                                                 1108
# 2                                                  132
# 3                                                 1386
# 4                                                  396
# ..                                                 ...
# 495                                                392
# 496                                                301
# 497                                                363
# 498                                                370
# 499                                                316
#
#      comment    like  share  Total Interactions
# 0          4    79.0   17.0                 100
# 1          5   130.0   29.0                 164
# 2          0    66.0   14.0                  80
# 3         58  1572.0  147.0                1777
# 4         19   325.0   49.0                 393
# ..       ...     ...    ...                 ...
# 495        5    53.0   26.0                  84
# 496        0    53.0   22.0                  75
# 497        4    93.0   18.0                 115
# 498        7    91.0   38.0                 136
# 499        0    91.0   28.0                 119
#
# [500 rows x 19 columns]

# %%
df.columns = [
    'page_total_likes',
    'post_type',
    'category',
    'post_month',
    'post_weekday',
    'post_hour',
    'paid',
    'lifetime_post_reach',
    'lifetime_post_impressions',
    'lifetime_engaged_users',
    'lifetime_post_consumers',
    'lifetime_post_consumptions',
    'lifetime_post_impressions_from_page_likes',
    'lifetime_post_reach_from_page_likes',
    'page_likes_engaged_users',
    'post_comments',
    'post_likes',
    'post_shares',
    'total_interactions'
]

# %%
df
# Out:
#      page_total_likes post_type  category  post_month  post_weekday  \
# 0              139441     Photo         2          12             4
# 1              139441    Status         2          12             3
# 2              139441     Photo         3          12             3
# 3              139441     Photo         2          12             2
# 4              139441     Photo         2          12             2
# ..                ...       ...       ...         ...           ...
# 495             85093     Photo         3           1             7
# 496             81370     Photo         2           1             5
# 497             81370     Photo         1           1             5
# 498             81370     Photo         3           1             4
# 499             81370     Photo         2           1             4
#
#      post_hour  paid  lifetime_post_reach  lifetime_post_impressions  \
# 0            3   0.0                 2752                       5091
# 1           10   0.0                10460                      19057
# 2            3   0.0                 2413                       4373
# 3           10   1.0                50128                      87991
# 4            3   0.0                 7244                      13594
# ..         ...   ...                  ...                        ...
# 495          2   0.0                 4684                       7536
# 496          8   0.0                 3480                       6229
# 497          2   0.0                 3778                       7216
# 498         11   0.0                 4156                       7564
# 499          4   NaN                 4188                       7292
#
#      lifetime_engaged_users  lifetime_post_consumers  \
# 0                       178                      109
# 1                      1457                     1361
# 2                       177                      113
# 3                      2211                      790
# 4                       671                      410
# ..                      ...                      ...
# 495                     733                      708
# 496                     537                      508
# 497                     625                      572
# 498                     626                      574
# 499                     564                      524
#
#      lifetime_post_consumptions  lifetime_post_impressions_from_page_likes  \
# 0                           159                                       3078
# 1                          1674                                      11710
# 2                           154                                       2812
# 3                          1119                                      61027
# 4                           580                                       6228
# ..                          ...                                        ...
# 495                         985                                       4750
# 496                         687                                       3961
# 497                         795                                       4742
# 498                         832                                       4534
# 499                         743                                       3861
#
#      lifetime_post_reach_from_page_likes  page_likes_engaged_users  \
# 0                                   1640                       119
# 1                                   6112                      1108
# 2                                   1503                       132
# 3                                  32048                      1386
# 4                                   3200                       396
# ..                                   ...                       ...
# 495                                 2876                       392
# 496                                 2104                       301
# 497                                 2388                       363
# 498                                 2452                       370
# 499                                 2200                       316
#
#      post_comments  post_likes  post_shares  total_interactions
# 0                4        79.0         17.0                 100
# 1                5       130.0         29.0                 164
# 2                0        66.0         14.0                  80
# 3               58      1572.0        147.0                1777
# 4               19       325.0         49.0                 393
# ..             ...         ...          ...                 ...
# 495              5        53.0         26.0                  84
# 496              0        53.0         22.0                  75
# 497              4        93.0         18.0                 115
# 498              7        91.0         38.0                 136
# 499              0        91.0         28.0                 119
#
# [500 rows x 19 columns]

# %% [markdown]
# ### Explain Columns:
#
# * page_total_likes: Number of people who have liked the company's page
# * post_type: Post can be Categorized into (`Photo`, `Status`, `Link`, `Video`)
# * category: it put each post in a certain Category (1:action `special offers and contests`, 2: product`direct aderisment` 3: inspiration `non-explicit brand related content`
# * post_month: at which month did the user upload the post (1-12)
# * post_weekday: at which day of the week did the user upload post (1-7)
# * post_hour: which hour did user upload post (it ranges from 1-24, not 1-12)
# * paid: did the company paid to promote the post (Yes, No)
# * lifetime_post_reach: Number of people who saw a page post(unique users), impressions are the number of times a page from a page is displayed, whether the post is clicked or not, people may see multiple
# * lifetime_post_impressions: impression of the same post for example someone might see a Page update in posts once and then a friend share it agian (non-unique) same as post_reach but non-unique
# * lifetime_engaged_users: Number of people who clicked anywhere in a post (click, comment, likes)(unique users)
# * lifetime_post_consumers:The number of people who clicked anywhere in post (just click or opend, doesn't require to like or comment) (unique)
# * lifetime_post_consumptions: The number of clicks anywhere in a post (same as consumer but consumption (not unique))
# * lifetime_post_impressions_from_page_likes: Total Number of impressions just from peopel who have followed page
# * lifetime_post_reach_from_page_likes: The number of peple who saw a page post because they have followed that page ( unique users )
# * page_likes_engaged_users: Number of people who followed page and clicked anywhere in a post (Uniqeue Users)
# * post_comments: total number of comments received by the post
# * post_likes: total number of likes received by the post
# * post_shares: total number of times the post was shared
# * total_interactions(Target): Total Number of interactions on the post ( sum of (comments, likes, shares))

# %%
df.info()
# we have much numeric
# while just 2 could be considered as categorical (category, paid)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   page_total_likes                           500 non-null    int64
#  1   post_type                                  500 non-null    object
#  2   category                                   500 non-null    int64
#  3   post_month                                 500 non-null    int64
#  4   post_weekday                               500 non-null    int64
#  5   post_hour                                  500 non-null    int64
#  6   paid                                       499 non-null    float64
#  7   lifetime_post_reach                        500 non-null    int64
#  8   lifetime_post_impressions                  500 non-null    int64
#  9   lifetime_engaged_users                     500 non-null    int64
#  10  lifetime_post_consumers                    500 non-null    int64
#  11  lifetime_post_consumptions                 500 non-null    int64
#  12  lifetime_post_impressions_from_page_likes  500 non-null    int64
#  13  lifetime_post_reach_from_page_likes        500 non-null    int64
#  14  page_likes_engaged_users                   500 non-null    int64
#  15  post_comments                              500 non-null    int64
#  16  post_likes                                 499 non-null    float64
#  17  post_shares                                496 non-null    float64
#  18  total_interactions                         500 non-null    int64
# dtypes: float64(3), int64(15), object(1)
# memory usage: 74.3+ KB

# %%
"""
* As a first impression it seems that data distributions is perfect
* Min, Max, Mean, std all of them make sinse excpet for some features may have larger Number
  so at some Point we have to use Normalization or Standarization
"""

df.describe()
# Out:
#        page_total_likes    category  post_month  post_weekday   post_hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              paid  lifetime_post_reach  lifetime_post_impressions  \
# count  499.000000            500.00000               5.000000e+02
# mean     0.278557          13903.36000               2.958595e+04
# std      0.448739          22740.78789               7.680325e+04
# min      0.000000            238.00000               5.700000e+02
# 25%      0.000000           3315.00000               5.694750e+03
# 50%      0.000000           5281.00000               9.051000e+03
# 75%      1.000000          13168.00000               2.208550e+04
# max      1.000000         180480.00000               1.110282e+06
#
#        lifetime_engaged_users  lifetime_post_consumers  \
# count              500.000000               500.000000
# mean               920.344000               798.772000
# std                985.016636               882.505013
# min                  9.000000                 9.000000
# 25%                393.750000               332.500000
# 50%                625.500000               551.500000
# 75%               1062.000000               955.500000
# max              11452.000000             11328.000000
#
#        lifetime_post_consumptions  lifetime_post_impressions_from_page_likes  \
# count                  500.000000                               5.000000e+02
# mean                  1415.130000                               1.676638e+04
# std                   2000.594118                               5.979102e+04
# min                      9.000000                               5.670000e+02
# 25%                    509.250000                               3.969750e+03
# 50%                    851.000000                               6.255500e+03
# 75%                   1463.000000                               1.486050e+04
# max                  19779.000000                               1.107833e+06
#
#        lifetime_post_reach_from_page_likes  page_likes_engaged_users  \
# count                           500.000000                500.000000
# mean                           6585.488000                609.986000
# std                            7682.009405                612.725618
# min                             236.000000                  9.000000
# 25%                            2181.500000                291.000000
# 50%                            3417.000000                412.000000
# 75%                            7989.000000                656.250000
# max                           51456.000000               4376.000000
#
#        post_comments   post_likes  post_shares  total_interactions
# count      500.00000   499.000000   496.000000          500.000000
# mean         7.48200   177.945892    27.266129          212.120000
# std         21.18091   323.398742    42.613292          380.233118
# min          0.00000     0.000000     0.000000            0.000000
# 25%          1.00000    56.500000    10.000000           71.000000
# 50%          3.00000   101.000000    19.000000          123.500000
# 75%          7.00000   187.500000    32.250000          228.500000
# max        372.00000  5172.000000   790.000000         6334.000000

# %% [markdown]
# ### Data Analyzing

# %%
"""
we can Categorize it into 
- High
- Medium
- Low
"""
df.page_total_likes.describe()

x = df['page_total_likes'].apply(lambda m:'Low' if m < 100000 else ('High' if m > 136393 else 'Medium'))

# %%
x.value_counts()
# Out:
# page_total_likes
# Medium    319
# High      119
# Low        62
# Name: count, dtype: int64

# %%
df[(df['page_total_likes'] < 136393) & (df['page_total_likes'] > 100000)]['page_total_likes']
# Out:
# 137    136013
# 138    136013
# 139    136013
# 140    136013
# 141    136013
#         ...
# 433    100732
# 434    100732
# 435    100732
# 436    100732
# 437    100732
# Name: page_total_likes, Length: 301, dtype: int64

# %%
change_post_time = ['post_month','post_weekday','post_hour']
plt.figure(figsize=(12,6))
for i in range(3):
    sns.barplot(x = change_post_time[i],y='total_interactions',data=df,hue=change_post_time[i])
    plt.show()
