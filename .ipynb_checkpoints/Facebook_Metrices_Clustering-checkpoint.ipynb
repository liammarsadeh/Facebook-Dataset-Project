# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('Facebook_metrics_Clustering.csv')

# %%
df
# Out:
#     post_type  category  post_month  post_weekday  post_hour  paid  \
# 0       Photo         2          12             4          3   0.0
# 1      Status         2          12             3         10   0.0
# 2       Photo         3          12             3          3   0.0
# 3       Photo         2          12             2         10   1.0
# 4       Photo         2          12             2          3   0.0
# ..        ...       ...         ...           ...        ...   ...
# 491     Photo         3           1             7          2   0.0
# 492     Photo         2           1             5          8   0.0
# 493     Photo         1           1             5          2   0.0
# 494     Photo         3           1             4         11   0.0
# 495     Photo         2           1             4          4   0.0
#
#      total_interactions  post_ratio_engaged_consumers  \
# 0                   100                      1.633028
# ...

# %%
df.describe()
# Out:
#          category  post_month  post_weekday   post_hour        paid  \
# count  496.000000  496.000000    496.000000  496.000000  496.000000
# mean     1.883065    7.086694      4.143145    7.832661    0.278226
# std      0.851876    3.276261      2.034469    4.378347    0.448578
# min      1.000000    1.000000      1.000000    1.000000    0.000000
# 25%      1.000000    4.000000      2.000000    3.000000    0.000000
# 50%      2.000000    7.000000      4.000000    9.000000    0.000000
# 75%      3.000000   10.000000      6.000000   11.000000    1.000000
# max      3.000000   12.000000      7.000000   23.000000    1.000000
#
#        total_interactions  post_ratio_engaged_consumers  \
# count          496.000000                    496.000000
# mean           211.606855                      1.187947
# std            381.252265                      0.228230
# min              0.000000                      1.000000
# 25%             71.000000                      1.048937
# ...

# %%
sns.histplot(x='total_interactions',data=df,kde=True,log_scale=True)
# Out:
# C:\Users\ryan1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# <Axes: xlabel='total_interactions', ylabel='Count'>

# %%
from sklearn.preprocessing import StandardScaler
s = StandardScaler()

# %%
s.fit(np.array(df['total_interactions']).reshape(496,1))
# Out:
# StandardScaler()

# %%
plt.hist(x=s.transform(np.array(df['total_interactions']).reshape(496,1)))
# Out:
# (array([474.,  13.,   6.,   2.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([-0.55559143,  1.10745305,  2.77049753,  4.43354201,  6.09658649,
#          7.75963097,  9.42267546, 11.08571994, 12.74876442, 14.4118089 ,
#         16.07485338]),
#  <BarContainer object of 10 artists>)
