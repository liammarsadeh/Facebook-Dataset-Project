# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,confusion_matrix,classification_report
from imblearn.over_sampling import SMOTENC
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier

# %%
df = pd.read_csv('Facebook_Classification_prdiction.csv')

# %%
df
# Out:
#     post_type  category  post_month  post_weekday  post_hour  paid  cluster_2
# 0       Photo         2          12             4          3   0.0  Not-Viral
# 1      Status         2          12             3         10   0.0  Not-Viral
# 2       Photo         3          12             3          3   0.0  Not-Viral
# 3       Photo         2          12             2         10   1.0      Viral
# 4       Photo         2          12             2          3   0.0  Not-Viral
# ..        ...       ...         ...           ...        ...   ...        ...
# 491     Photo         3           1             7          2   0.0  Not-Viral
# 492     Photo         2           1             5          8   0.0  Not-Viral
# 493     Photo         1           1             5          2   0.0  Not-Viral
# 494     Photo         3           1             4         11   0.0  Not-Viral
# 495     Photo         2           1             4          4   0.0  Not-Viral
#
# [496 rows x 7 columns]

# %%
df = df.rename(columns={'cluster_2':'Target'})

# %%
df['Target'] = df['Target'].map({'Not-Viral':0,'Viral':1})

# %% [markdown]
# #### PreProcess Data
# 1. Encode `Post Type`
# 3. We don't have any Scalling Columns For `Classification Prediction`
# 4. We have To solve Imbalance Data Problem

# %%
df
# Out:
#     post_type  category  post_month  post_weekday  post_hour  paid  Target
# 0       Photo         2          12             4          3   0.0       0
# 1      Status         2          12             3         10   0.0       0
# 2       Photo         3          12             3          3   0.0       0
# 3       Photo         2          12             2         10   1.0       1
# 4       Photo         2          12             2          3   0.0       0
# ..        ...       ...         ...           ...        ...   ...     ...
# 491     Photo         3           1             7          2   0.0       0
# 492     Photo         2           1             5          8   0.0       0
# 493     Photo         1           1             5          2   0.0       0
# 494     Photo         3           1             4         11   0.0       0
# 495     Photo         2           1             4          4   0.0       0
#
# [496 rows x 7 columns]

# %%
df.groupby(['paid','Target']).size() # It seems like Paid Isn't the one deciding which post is viral or not
# Out:
# paid  Target
# 0.0   0         331
#       1          27
# 1.0   0         113
#       1          25
# dtype: int64

# %%
df.groupby(['post_type','Target']).size() # Most of the post that goes Viral are Photos
# Out:
# post_type  Target
# Link       0          18
#            1           2
# Photo      0         376
#            1          48
# Status     0          44
#            1           1
# Video      0           6
#            1           1
# dtype: int64

# %%
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from xgboost import XGBClassifier

# %%
X = df.drop(columns='Target')
y = df['Target']

# %%
ratio = y.value_counts()[0] / y.value_counts()[1]

# %%
ct = make_column_transformer(
    (OneHotEncoder(handle_unknown='ignore'),['post_type']),remainder='passthrough')


pipe = make_pipeline(ct,
    XGBClassifier(
    n_estimators=300,
    max_depth=3,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=1,        # L1
    reg_lambda=2,       # L2
    scale_pos_weight=ratio, 
    random_state=42
)

)
pipe2 = make_pipeline(ct,
                      GradientBoostingClassifier(
                          n_estimators=400,
                          learning_rate=0.02,
                          max_depth=4,
                          subsample=0.8,
                      random_state=42))

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.25,
    stratify=y,
    random_state=42
)

# %%
param_grid = {
    'xgbclassifier__n_estimators':[300,500,700,1000],
    'xgbclassifier__scale_pos_weight': [3, 4, 5, 8],
    'xgbclassifier__max_depth': [3, 4, 5],
    'xgbclassifier__learning_rate': [0.01, 0.02, 0.05],
    'xgbclassifier__min_child_weight': [5, 7, 10]
}

grid_search = GridSearchCV(pipe, param_grid, scoring='recall', cv=5,n_jobs=-1)
grid_search.fit(X_train, y_train)

print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'xgbclassifier__learning_rate': 0.01, 'xgbclassifier__max_depth': 3, 'xgbclassifier__min_child_weight': 10, 'xgbclassifier__n_estimators': 700, 'xgbclassifier__scale_pos_weight': 8}

# %%
grid_search.best_score_
# Out:
# np.float64(0.5428571428571429)

# %%
pipe2.fit(X_train,y_train)
y_logits_2 = pipe2.predict_proba(X_test)[:,1]
for t in [0.5, 0.4, 0.3, 0.25, 0.2]: # The lower The Threshold The Higher Model Picks 1
    y_pred = (y_logits_2 >= t).astype(int)
    print(f"\nThreshold: {t}")
    print(classification_report(y_test, y_pred, target_names=["Not-Viral", "Viral"]))
# Out:
# Threshold: 0.5
#               precision    recall  f1-score   support
#
#    Not-Viral       0.90      0.99      0.94       111
#        Viral       0.50      0.08      0.13        13
#
#     accuracy                           0.90       124
#    macro avg       0.70      0.53      0.54       124
# weighted avg       0.86      0.90      0.86       124
#
#
# Threshold: 0.4
#               precision    recall  f1-score   support
#
#    Not-Viral       0.91      0.97      0.94       111
#        Viral       0.40      0.15      0.22        13
#
#     accuracy                           0.89       124
#    macro avg       0.65      0.56      0.58       124
# weighted avg       0.85      0.89      0.86       124
#
#
# Threshold: 0.3
#               precision    recall  f1-score   support
#
#    Not-Viral       0.92      0.95      0.94       111
#        Viral       0.44      0.31      0.36        13
#
#     accuracy                           0.89       124
# ...

# %%
y_pred_gb = (y_logits_2 >= 0.3).astype(int)
cf_gb = confusion_matrix(y_test,y_pred_gb)

# %%
cf_gb
# Out:
# array([[106,   5],
#        [  9,   4]])

# %%
from sklearn.metrics import classification_report

# Training predictions
y_train_prob_gb = pipe2.predict_proba(X_train)[:,1]
y_train_pred_gb = (y_train_prob_gb >= 0.3).astype(int)
print("Train metrics:\n", classification_report(y_train, y_train_pred_gb, target_names=['Not-Viral','Viral']))

# Test predictions
y_test_prob_gb = pipe2.predict_proba(X_test)[:,1]
y_test_pred_gb = (y_test_prob_gb >= 0.3).astype(int)
print("Test metrics:\n", classification_report(y_test, y_test_pred_gb, target_names=['Not-Viral','Viral']))
# Out:
# Train metrics:
#                precision    recall  f1-score   support
#
#    Not-Viral       0.99      0.99      0.99       333
#        Viral       0.92      0.90      0.91        39
#
#     accuracy                           0.98       372
#    macro avg       0.95      0.94      0.95       372
# weighted avg       0.98      0.98      0.98       372
#
# Test metrics:
#                precision    recall  f1-score   support
#
#    Not-Viral       0.92      0.95      0.94       111
#        Viral       0.44      0.31      0.36        13
#
#     accuracy                           0.89       124
#    macro avg       0.68      0.63      0.65       124
# weighted avg       0.87      0.89      0.88       124

# %% [markdown]
# #### XGBoost

# %%
pipe.fit(X_train, y_train)
y_logits = pipe.predict_proba(X_test)[:, 1]
for t in [0.5, 0.4, 0.3, 0.25, 0.2]: # The lower The Threshold The Higher Model Picks 1
    y_pred = (y_logits >= t).astype(int)
    print(f"\nThreshold: {t}")
    print(classification_report(y_test, y_pred, target_names=["Not-Viral", "Viral"]))
# Out:
# Threshold: 0.5
#               precision    recall  f1-score   support
#
#    Not-Viral       0.94      0.87      0.91       111
#        Viral       0.33      0.54      0.41        13
#
#     accuracy                           0.84       124
#    macro avg       0.64      0.71      0.66       124
# weighted avg       0.88      0.84      0.85       124
#
#
# Threshold: 0.4
#               precision    recall  f1-score   support
#
#    Not-Viral       0.95      0.81      0.87       111
#        Viral       0.28      0.62      0.38        13
#
#     accuracy                           0.79       124
#    macro avg       0.61      0.71      0.63       124
# weighted avg       0.88      0.79      0.82       124
#
#
# Threshold: 0.3
#               precision    recall  f1-score   support
#
#    Not-Viral       0.94      0.71      0.81       111
#        Viral       0.20      0.62      0.30        13
#
#     accuracy                           0.70       124
# ...

# %%
from sklearn.metrics import classification_report

# Training predictions
y_train_prob = pipe.predict_proba(X_train)[:,1]
y_train_pred = (y_train_prob >= 0.5).astype(int)
print("Train metrics:\n", classification_report(y_train, y_train_pred, target_names=['Not-Viral','Viral']))

y_test_prob = pipe.predict_proba(X_test)[:,1]
y_test_pred = (y_test_prob >= 0.5).astype(int)
print("Test metrics:\n", classification_report(y_test, y_test_pred, target_names=['Not-Viral','Viral']))
# Out:
# Train metrics:
#                precision    recall  f1-score   support
#
#    Not-Viral       1.00      0.92      0.96       333
#        Viral       0.59      1.00      0.74        39
#
#     accuracy                           0.93       372
#    macro avg       0.80      0.96      0.85       372
# weighted avg       0.96      0.93      0.94       372
#
# Test metrics:
#                precision    recall  f1-score   support
#
#    Not-Viral       0.94      0.87      0.91       111
#        Viral       0.33      0.54      0.41        13
#
#     accuracy                           0.84       124
#    macro avg       0.64      0.71      0.66       124
# weighted avg       0.88      0.84      0.85       124

# %%
y_pred_xgb = (y_logits >= 0.5).astype(int)
cf_xgb = confusion_matrix(y_test,y_pred_xgb)
cf_xgb
# Out:
# array([[97, 14],
#        [ 6,  7]])

# %% [markdown]
# #### Visualize Results

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, thresholds = precision_recall_curve(y_test, y_pred)

plt.plot(recall, precision)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("PR Curve")
plt.show()

# %%
plt.title('Gradient Boost Confustion Matrix')

sns.heatmap(cf_gb,annot=True,fmt='.0f',cmap='Blues')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# %%
plt.title('XGBoost Confusion Matrix')
sns.heatmap(cf_xgb,annot=True,fmt='.0f',cmap='Blues')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# %%
thresholds = [0.5, 0.4, 0.3, 0.25, 0.2]

recall_not_viral_xgb = [0.87, 0.81, 0.71, 0.65, 0.57]
recall_viral_xgb = [0.54, 0.62, 0.62, 0.69, 0.69]

plt.figure(figsize=(8,5))
plt.plot(thresholds, recall_not_viral_xgb, marker='o', label='Not-Viral Recall', color='blue')
plt.plot(thresholds, recall_viral_xgb, marker='o', label='Viral Recall', color='red')

plt.gca().invert_xaxis() 
plt.title('Recall vs Threshold || XGB')
plt.xlabel('Threshold')
plt.ylabel('Recall')
plt.xticks(thresholds)
plt.ylim(0, 1)
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt


recall_not_viral = [0.99, 0.97, 0.95, 0.94, 0.91]
recall_viral     = [0.08, 0.15, 0.31, 0.31, 0.38]

plt.figure(figsize=(8,5))
plt.plot(thresholds, recall_not_viral, marker='o', label='Not-Viral Recall', color='blue')
plt.plot(thresholds, recall_viral, marker='o', label='Viral Recall', color='red')

plt.gca().invert_xaxis()
plt.title('Recall vs Threshold || GB')
plt.xlabel('Threshold')
plt.ylabel('Recall')
plt.xticks(thresholds)
plt.ylim(0, 1)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# #### Conclusion
# * We have tried my best to play with Parameter Esspicially in Boosting But Model Still Overfitting
# * And We have Tried To Play with Threshold And still model is `Overfitting`
# * And we Also Tried To do The `OverSampling` SMOTE but it didn't also Work
# * Main Problem is The samples are Few and Model Can't generate or Understand Patteren with a Few Samples
